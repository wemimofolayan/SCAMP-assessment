# %% [markdown]
# <a href="https://colab.research.google.com/github/wemimofolayan/SCAMP-assessment/blob/master/Titianic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pycaret

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
sub = pd.read_csv('/content/gender_submission.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000   204       889
# unique          NaN         NaN         NaN  ...         NaN   147         3
# top             NaN         NaN         NaN  ...         NaN    G6         S
# freq            NaN         NaN         NaN  ...         NaN     4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208   NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429   NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000   NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400   NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200   NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000   NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200   NaN       NaN
#
# [11 rows x 12 columns]

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.drop(['Name','PassengerId', 'Cabin'], axis=1, inplace=True)
test.drop(['Name','PassengerId', 'Cabin'], axis=1, inplace=True)

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.Embarked.fillna('S', inplace=True)

# %%
test.Fare.fillna(32.20, inplace=True)

# %%
train.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
test.Age.describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
test.Age.fillna(27, inplace=True)
train.Age.fillna(28, inplace=True)

# %%
#train.Sex.value_counts()
test.Sex.value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
cat_cols = ['Sex','Embarked']
train=pd.get_dummies(train, prefix=cat_cols,columns=cat_cols)
test=pd.get_dummies(test, prefix=cat_cols, columns=cat_cols)

# %%
 
#train['Embarked'].replace('S',3, inplace=True)
#train['Embarked'].replace('C',2, inplace=True)
#train['Embarked'].replace('Q',1, inplace=True)
 
#test['Embarked'].replace('S',3, inplace=True)
#test['Embarked'].replace('C',2, inplace=True)
#test['Embarked'].replace('Q',1, inplace=True)

# %%
 
#train['Sex'].replace('female',1, inplace=True)
#train['Sex'].replace('male',2, inplace=True)
#n_train['Sex'].replace('High',1, inplace=True)
 
#test['Sex'].replace('female',1, inplace=True)
#test['Sex'].replace('male',2, inplace=True)
#df2['Sex'].replace('High',1, inplace=True)

# %%
train.head()
##n_test.head()
# Out:
#    Survived  Pclass   Age  SibSp  ...  Sex_male Embarked_C  Embarked_Q  Embarked_S
# 0         0       3  22.0      1  ...         1          0           0           1
# 1         1       1  38.0      1  ...         0          1           0           0
# 2         1       3  26.0      0  ...         0          0           0           1
# 3         1       1  35.0      1  ...         0          0           0           1
# 4         0       3  35.0      0  ...         1          0           0           1
#
# [5 rows x 12 columns]

# %%
#train.Ticket.value_counts()
##test.Ticket.value_counts()

# %%
#data_clean = [train, test]

# %%
#for dataset in data_clean:    
    #Discrete variables
    #dataset['FamilySize'] = dataset ['SibSp'] + dataset['Parch'] + 1
 
    #dataset['IsAlone'] = 1 #initialize to yes/1 is alone
    #dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
 
    #quick and dirty code split title from name: http://www.pythonforbeginners.com/dictionary/python-split
    #dataset['Title'] = dataset['Name'].str.split(", ", expand=True)[1].str.split(".", expand=True)[0]
 
 
    #Continuous variable bins; qcut vs cut: https://stackoverflow.com/questions/30211923/what-is-the-difference-between-pandas-qcut-and-pandas-cut
    #Fare Bins/Buckets using qcut or frequency bins: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.qcut.html
    #dataset['FareBin'] = pd.qcut(dataset['Fare'], 4)
 
    #Age Bins/Buckets using cut or value bins: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.cut.html
    #dataset['AgeBin'] = pd.cut(dataset['Age'].astype(int), 5)
 
 
    
#cleanup rare title names
#print(data1['Title'].value_counts())
#stat_min = 10 #while small is arbitrary, we'll use the common minimum in statistics: http://nicholasjjackson.com/2012/03/08/sample-size-is-10-a-magic-number/
#title_names = (df_train1['Title'].value_counts() < stat_min) #this will create a true false series with title name as index
 
#apply and lambda functions are quick and dirty code to find and replace with fewer lines of code: https://community.modeanalytics.com/python/tutorial/pandas-groupby-and-python-lambda-functions/
#df_train1['Title'] = df_train1['Title'].apply(lambda x: 'Misc' if title_names.loc[x] == True else x)
#print(df_train1['Title'].value_counts())
#print("-"*10)

# %%
train.drop('Ticket', axis=1, inplace=True)
test.drop('Ticket', axis=1, inplace=True)

# %%
train.info()
#test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    float64
#  3   SibSp       891 non-null    int64
#  4   Parch       891 non-null    int64
#  5   Fare        891 non-null    float64
#  6   Sex_female  891 non-null    uint8
#  7   Sex_male    891 non-null    uint8
#  8   Embarked_C  891 non-null    uint8
#  9   Embarked_Q  891 non-null    uint8
#  10  Embarked_S  891 non-null    uint8
# dtypes: float64(2), int64(4), uint8(5)
# memory usage: 46.2 KB

# %%
from pycaret.classification import *

# %%
 
exp_reg = setup(train, target = "Survived")
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002row0_col1" class="data row0 col1" >4890</td>
#             </tr>
#             <tr>
#                         <th id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2ca3cd4e_db1f_11ea_bf33_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
 compare_models()
# Out:
# <style  type="text/css" >
#     #T_4984454c_db1f_11ea_bf33_0242ac1c0002 th {
#           text-align: left;
#     }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4984454c_db1f_11ea_bf33_0242ac1c0002row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
 model = create_model("catboost")
# Out:
# <style  type="text/css" >
#     #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col5 {
#             background:  yellow;
#         }    #T_53009e22_db1f_11ea_bf33_0242ac1c0002row10_col6 {
#             background:  yellow;
# ...

# %%
 tuned_model = tune_model(model)
# Out:
# <style  type="text/css" >
#     #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col5 {
#             background:  yellow;
#         }    #T_80d12808_db1f_11ea_bf33_0242ac1c0002row10_col6 {
#             background:  yellow;
# ...

# %%
 predictions = predict_model(tuned_model)
# Out:
#                  Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  CatBoost Classifier    0.8246  0.8594  ...  0.7487  0.6161  0.6237
#
# [1 rows x 8 columns]

# %%
 finalize_model(tuned_model)

# %%
 
predictions = predict_model(tuned_model, data = test)
sub["Survived"] = predictions['Label']
sub.to_csv('last_prediction.csv',index= False)
sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0
